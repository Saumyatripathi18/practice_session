# %%
#question1
for i in range(2000,3201):
    print(i,', ',end='')
    if i%7==0 & i%5 !=0 | i%5 !=5:
        print(i,'is divisible by 7 and not a multiple of 5')
    else:
        print(i,'is not divisible by 7 or can be a multiple of 5 divisible by 7')
# Out:
# 2000 , 2000 is not divisible by 7 or can be a multiple of 5 divisible by 7
# 2001 , 2001 is not divisible by 7 or can be a multiple of 5 divisible by 7
# 2002 , 2002 is divisible by 7 and not a multiple of 5
# 2003 , 2003 is not divisible by 7 or can be a multiple of 5 divisible by 7
# 2004 , 2004 is not divisible by 7 or can be a multiple of 5 divisible by 7
# 2005 , 2005 is not divisible by 7 or can be a multiple of 5 divisible by 7
# 2006 , 2006 is not divisible by 7 or can be a multiple of 5 divisible by 7
# 2007 , 2007 is not divisible by 7 or can be a multiple of 5 divisible by 7
# 2008 , 2008 is not divisible by 7 or can be a multiple of 5 divisible by 7
# 2009 , 2009 is divisible by 7 and not a multiple of 5
# 2010 , 2010 is not divisible by 7 or can be a multiple of 5 divisible by 7
# 2011 , 2011 is not divisible by 7 or can be a multiple of 5 divisible by 7
# 2012 , 2012 is not divisible by 7 or can be a multiple of 5 divisible by 7
# ...

# %%
#question2
a=input('enter first name: ')
b=input('enter last name: ')
print(a[::-1],' ',b[::-1])
# Out:
# enter first name: saumya
# enter last name: tripathi
# aymuas   ihtapirt

# %%
#question3
diameter=12
r=diameter/2
volume=4/3*3.1415*r**3
print('volume of a sphere is',volume)
# Out:
# volume of a sphere is 904.752
