# %%
import pandas as pd

# %%
import glob

# %%
path='D:\\saumya\\AReM\\bending1'

# %%
files = glob.glob(path + "/*.csv")

# %%
data_frame = pd.DataFrame()

# %%
content = []

# %%
for filename in files:
    
    # reading content of csv file
    # content.append(filename)
    df = pd.read_csv(filename, index_col=None,skiprows=4)
    content.append(df)

# %%
data_frame = pd.concat(content)
print(data_frame)
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      39.25       0.43      22.75       0.43      33.75
# 1                250      39.25       0.43      23.00       0.00      33.00
# 2                500      39.25       0.43      23.25       0.43      33.00
# 3                750      39.50       0.50      23.00       0.71      33.00
# 4               1000      39.50       0.50      24.00       0.00      33.00
# ..               ...        ...        ...        ...        ...        ...
# 475           118750      44.25       0.83      16.25       1.30      24.00
# 476           119000      44.00       0.71      11.00       1.00      24.00
# 477           119250      44.25       0.43      10.25       1.30      22.75
# 478           119500      43.75       0.43       7.33       2.87      21.50
# 479           119750      44.50       0.50       3.00       1.22      21.50
#
#      var_rss23
# 0         1.30
# 1         0.00
# ...

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
data_frame.to_excel('D:\\saumya\\saumya.xlsx')

# %%
print(content)
# Out:
# [     # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      39.25       0.43      22.75       0.43      33.75
# 1                250      39.25       0.43      23.00       0.00      33.00
# 2                500      39.25       0.43      23.25       0.43      33.00
# 3                750      39.50       0.50      23.00       0.71      33.00
# 4               1000      39.50       0.50      24.00       0.00      33.00
# ..               ...        ...        ...        ...        ...        ...
# 475           118750      43.33       0.47      25.00       0.00      30.00
# 476           119000      43.50       0.50      25.50       0.50      30.00
# 477           119250      43.50       0.50      24.75       0.43      30.00
# 478           119500      43.50       0.50      24.33       0.47      30.00
# 479           119750      43.50       0.50      24.25       0.43      30.00
#
#      var_rss23
# 0          1.3
# 1          0.0
# ...

# %%
content[6]
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      42.00       0.00      18.50       0.50      12.00
# 1                250      42.00       0.00      18.00       0.00      11.33
# 2                500      42.75       0.43      16.75       1.79      18.25
# 3                750      42.50       0.50      16.75       0.83      19.00
# 4               1000      43.00       0.82      16.25       0.83      18.00
# ..               ...        ...        ...        ...        ...        ...
# 475           118750      44.25       0.83      16.25       1.30      24.00
# 476           119000      44.00       0.71      11.00       1.00      24.00
# 477           119250      44.25       0.43      10.25       1.30      22.75
# 478           119500      43.75       0.43       7.33       2.87      21.50
# 479           119750      44.50       0.50       3.00       1.22      21.50
#
#      var_rss23
# 0         0.00
# 1         0.94
# ...

# %%
content[7]
# Out:
#              # Task: bending1
# 0        # Frequency (Hz): 20
# 1  # Clock (millisecond): 250
# 2   # Duration (seconds): 120

# %%
content[8]
# Out:
#              # Task: bending1
# 0        # Frequency (Hz): 20
# 1  # Clock (millisecond): 250
# 2   # Duration (seconds): 120

# %%
content[5]
# Out:
#      # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                  0      41.25       1.30      24.00       0.00      32.33
# 1                250      41.00       1.00      22.50       1.12      33.50
# 2                500      44.25       0.83      21.75       0.83      31.50
# 3                750      45.00       0.00      20.00       1.22      30.00
# 4               1000      45.25       0.43      15.25       2.86      30.50
# ..               ...        ...        ...        ...        ...        ...
# 475           118750      43.50       0.50      14.50       1.12      22.50
# 476           119000      44.00       0.00      18.00       0.71      22.25
# 477           119250      44.25       0.83      16.50       2.29      23.25
# 478           119500      42.50       0.87      13.50       1.50      16.25
# 479           119750      41.50       0.50      15.25       1.79      13.00
#
#      var_rss23
# 0         0.94
# 1         0.87
# ...

# %%
path='D:\\saumya\\AReM\\bending2'

# %%
files1=glob.glob(path+"/*.csv")

# %%
data_frame1=pd.DataFrame()

# %%
content1=[]

# %%
for filename in files1:
    
    # reading content of csv file
    # content.append(filename)
    df1 = pd.read_csv(filename, index_col=None,skiprows=4)
    content1.append(df1)

# %%
data_frame1 = pd.concat(content1)
print(data_frame1)
# Out:
#     # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                 0      23.75       0.43      24.00       0.00      24.67
# 1               250      22.67       0.94      24.00       0.00      24.67
# 2               500      21.33       0.47      24.00       0.00      24.75
# 3               750      21.00       0.00      24.00       0.00      25.25
# 4              1000      23.00       0.71      23.75       0.43      24.75
# ..              ...        ...        ...        ...        ...        ...
# 475          118750      27.00       0.00      14.00       0.00       6.50
# 476          119000      27.00       0.00      15.00       0.00       4.00
# 477          119250      27.00       0.00      14.25       0.83       4.00
# 478          119500      27.00       0.00      13.33       1.25       1.50
# 479          119750      26.50       0.50      15.00       0.00       3.00
#
#      var_rss23
# 0         0.47
# 1         0.94
# 2         0.83
# ...

# %%
path='D:\\saumya\\AReM\\cycling'

# %%
files2=glob.glob(path+"/*.csv")
content2=[]
for filename in files2:
    
    # reading content of csv file
    # content.append(filename)
    df2 = pd.read_csv(filename, index_col=None,skiprows=4)
    content2.append(df2)
data_frame2 = pd.concat(content2)
print(data_frame2)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-76-a22bef006f4e> in <module>
#       5     # reading content of csv file
#       6     # content.append(filename)
# ----> 7     df2 = pd.read_csv(filename, index_col=None,skiprows=4)
#       8     content2.append(df2)
#       9 data_frame2 = pd.concat(content2)
#
# ...

# %%
content_final=[data_frame,data_frame1]

# %%
pd.concat(content_final)
# Out:
#     # Columns: time  avg_rss12  var_rss12  avg_rss13  var_rss13  avg_rss23  \
# 0                 0      39.25       0.43      22.75       0.43      33.75
# 1               250      39.25       0.43      23.00       0.00      33.00
# 2               500      39.25       0.43      23.25       0.43      33.00
# 3               750      39.50       0.50      23.00       0.71      33.00
# 4              1000      39.50       0.50      24.00       0.00      33.00
# ..              ...        ...        ...        ...        ...        ...
# 475          118750      27.00       0.00      14.00       0.00       6.50
# 476          119000      27.00       0.00      15.00       0.00       4.00
# 477          119250      27.00       0.00      14.25       0.83       4.00
# 478          119500      27.00       0.00      13.33       1.25       1.50
# 479          119750      26.50       0.50      15.00       0.00       3.00
#
#      var_rss23
# 0          1.3
# 1          0.0
# 2          0.0
# ...
