# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes =='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
type(df.dtypes[df.dtypes =='object'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes =='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[['Name','Sex','Ticket']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# ...

# %%
df[df.dtypes[df.dtypes =='object'].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df.dtypes == 'int64'
# Out:
# PassengerId     True
# Survived        True
# Pclass          True
# Name           False
# Sex            False
# Age            False
# SibSp           True
# Parch           True
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes[df.dtypes=='int64']
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# SibSp          int64
# Parch          int64
# dtype: object

# %%
df.dtypes[df.dtypes=='int64'].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch'], dtype='object')

# %%
df[df.dtypes[df.dtypes=='int64'].index]
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes=='float64'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df.dtypes[df.dtypes=='float64']
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
df.dtypes[df.dtypes=='float64'].index
# Out:
# Index(['Age', 'Fare'], dtype='object')

# %%
df[df.dtypes[df.dtypes=='float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
(df.dtypes =='object') | (df.dtypes=='float64')
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age             True
# SibSp          False
# Parch          False
# Ticket          True
# Fare            True
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[(df.dtypes =='object') | (df.dtypes=='float64')]
# Out:
# Name         object
# Sex          object
# Age         float64
# Ticket       object
# Fare        float64
# Cabin        object
# Embarked     object
# dtype: object

# %%
df[df.dtypes[(df.dtypes =='object') | (df.dtypes=='float64')].index]
# Out:
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df1=df[df.dtypes[df.dtypes=='object'].index]

# %%
df1.describe()
# Out:
#                            Name   Sex    Ticket Cabin Embarked
# count                       891   891       891   204      889
# unique                      891     2       681   147        3
# top     Oreskovic, Miss. Marija  male  CA. 2343    G6        S
# freq                          1   577         7     4      644

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df['Name'][0:5:1]
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df['Name'].head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['sudh']='kumar'

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['PassengerId']=0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              0         0       3
# 1              0         1       1
# 2              0         1       3
# 3              0         1       1
# 4              0         0       3
# ..           ...       ...     ...
# 886            0         0       2
# 887            0         1       1
# 888            0         0       3
# 889            0         1       1
# 890            0         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Age'].isnull() == True
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
import numpy as np

# %%
row_index_null=np.where(df['Age'].isnull() == True)

# %%
row_index_null
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154, 158, 159, 166, 168, 176, 180, 181, 185, 186,
#         196, 198, 201, 214, 223, 229, 235, 240, 241, 250, 256, 260, 264,
#         270, 274, 277, 284, 295, 298, 300, 301, 303, 304, 306, 324, 330,
#         334, 335, 347, 351, 354, 358, 359, 364, 367, 368, 375, 384, 388,
#         409, 410, 411, 413, 415, 420, 425, 428, 431, 444, 451, 454, 457,
#         459, 464, 466, 468, 470, 475, 481, 485, 490, 495, 497, 502, 507,
#         511, 517, 522, 524, 527, 531, 533, 538, 547, 552, 557, 560, 563,
#         564, 568, 573, 578, 584, 589, 593, 596, 598, 601, 602, 611, 612,
#         613, 629, 633, 639, 643, 648, 650, 653, 656, 667, 669, 674, 680,
#         692, 697, 709, 711, 718, 727, 732, 738, 739, 740, 760, 766, 768,
#         773, 776, 778, 783, 790, 792, 793, 815, 825, 826, 828, 832, 837,
# ...

# %%
df.iloc[0]
# Out:
# PassengerId                          0
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# sudh                             kumar
# Name: 0, dtype: object

# %%
df.iloc[[0,3,6]]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            0         0       3
# 3            0         1       1
# 6            0         0       1
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    male  22.0      1      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 6                       McCarthy, Mr. Timothy J    male  54.0      0      0
#
#       Ticket     Fare Cabin Embarked   sudh
# 0  A/5 21171   7.2500   NaN        S  kumar
# 3     113803  53.1000  C123        S  kumar
# 6      17463  51.8625   E46        S  kumar

# %%
df.iloc[row_index_null]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              0         0       3                          Moran, Mr. James
# 17             0         1       2              Williams, Mr. Charles Eugene
# 19             0         1       3                   Masselmani, Mrs. Fatima
# 26             0         0       3                   Emir, Mr. Farred Chehab
# 28             0         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859            0         0       3                          Razi, Mr. Raihed
# 863            0         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868            0         0       3               van Melkebeke, Mr. Philemon
# 878            0         0       3                        Laleff, Mr. Kristo
# 888            0         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
type(df.iloc[row_index_null])
# Out:
# pandas.core.frame.DataFrame

# %%
df.iloc[row_index_null]['Name']
# Out:
# 5                              Moran, Mr. James
# 17                 Williams, Mr. Charles Eugene
# 19                      Masselmani, Mrs. Fatima
# 26                      Emir, Mr. Farred Chehab
# 28                O'Dwyer, Miss. Ellen "Nellie"
#                          ...
# 859                            Razi, Mr. Raihed
# 863           Sage, Miss. Dorothy Edith "Dolly"
# 868                 van Melkebeke, Mr. Philemon
# 878                          Laleff, Mr. Kristo
# 888    Johnston, Miss. Catherine Helen "Carrie"
# Name: Name, Length: 177, dtype: object

# %%
type(df.iloc[row_index_null]['Name'])
# Out:
# pandas.core.series.Series

# %%
type(df.iloc[row_index_null][['Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count        891.0  891.000000  891.000000  714.000000  891.000000
# mean           0.0    0.383838    2.308642   29.699118    0.523008
# std            0.0    0.486592    0.836071   14.526497    1.102743
# min            0.0    0.000000    1.000000    0.420000    0.000000
# 25%            0.0    0.000000    2.000000   20.125000    0.000000
# 50%            0.0    0.000000    3.000000   28.000000    0.000000
# 75%            0.0    1.000000    3.000000   38.000000    1.000000
# max            0.0    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Fare']==512.329200
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
np.where(df['Fare']==512.329200)
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
max_fare=np.where(df['Fare']==512.329200)

# %%
df.iloc[max_fare]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258            0         1       1                    Ward, Miss. Anna
# 679            0         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737            0         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#       sudh
# 258  kumar
# 679  kumar
# 737  kumar

# %%
df.iloc[max_fare]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
max(df['Fare'])
# Out:
# 512.3292

# %%
np.where(df['Fare']==max(df['Fare']))
# Out:
# (array([258, 679, 737], dtype=int64),)

# %%
df.iloc[np.where(df['Fare']==max(df['Fare']))][['Name','Age']]
# Out:
#                                    Name   Age
# 258                    Ward, Miss. Anna  35.0
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0
# 737              Lesurer, Mr. Gustave J  35.0

# %%
df[df['Fare']==max(df['Fare'])][['Name','Age']]
# Out:
#                                    Name   Age
# 258                    Ward, Miss. Anna  35.0
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0
# 737              Lesurer, Mr. Gustave J  35.0

# %%
df.iloc[np.where(df['Fare']==min(df['Fare']))][['Name','Age']]
# Out:
#                                  Name   Age
# 179               Leonard, Mr. Lionel  36.0
# 263             Harrison, Mr. William  40.0
# 271      Tornquist, Mr. William Henry  25.0
# 277       Parkes, Mr. Francis "Frank"   NaN
# 302   Johnson, Mr. William Cahoone Jr  19.0
# 413    Cunningham, Mr. Alfred Fleming   NaN
# 466             Campbell, Mr. William   NaN
# 481  Frost, Mr. Anthony Wood "Archie"   NaN
# 597               Johnson, Mr. Alfred  49.0
# 633     Parr, Mr. William Henry Marsh   NaN
# 674        Watson, Mr. Ennis Hastings   NaN
# 732              Knight, Mr. Robert J   NaN
# 806            Andrews, Mr. Thomas Jr  39.0
# 815                  Fry, Mr. Richard   NaN
# 822   Reuchlin, Jonkheer. John George  38.0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              0         0       3
# 1              0         1       1
# 2              0         1       3
# 3              0         1       1
# 4              0         0       3
# ..           ...       ...     ...
# 886            0         0       2
# 887            0         1       1
# 888            0         0       3
# 889            0         1       1
# 890            0         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[np.where(df['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              0         0       3         Braund, Mr. Owen Harris  male
# 4              0         0       3        Allen, Mr. William Henry  male
# 5              0         0       3                Moran, Mr. James  male
# 6              0         0       1         McCarthy, Mr. Timothy J  male
# 7              0         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883            0         0       2   Banfield, Mr. Frederick James  male
# 884            0         0       3          Sutehall, Mr. Henry Jr  male
# 886            0         0       2           Montvila, Rev. Juozas  male
# 889            0         1       1           Behr, Mr. Karl Howell  male
# 890            0         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked   sudh
# ...

# %%
df.iloc[np.where(df['Sex']=='female')]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              0         1       1
# 2              0         1       3
# 3              0         1       1
# 8              0         1       3
# 9              0         1       2
# ..           ...       ...     ...
# 880            0         1       2
# 882            0         0       3
# 885            0         0       3
# 887            0         1       1
# 888            0         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df['Sex']=='male']
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              0         0       3         Braund, Mr. Owen Harris  male
# 4              0         0       3        Allen, Mr. William Henry  male
# 5              0         0       3                Moran, Mr. James  male
# 6              0         0       1         McCarthy, Mr. Timothy J  male
# 7              0         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883            0         0       2   Banfield, Mr. Frederick James  male
# 884            0         0       3          Sutehall, Mr. Henry Jr  male
# 886            0         0       2           Montvila, Rev. Juozas  male
# 889            0         1       1           Behr, Mr. Karl Howell  male
# 890            0         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked   sudh
# ...

# %%
df[df['Age'].isnull()]['Name']
# Out:
# 5                              Moran, Mr. James
# 17                 Williams, Mr. Charles Eugene
# 19                      Masselmani, Mrs. Fatima
# 26                      Emir, Mr. Farred Chehab
# 28                O'Dwyer, Miss. Ellen "Nellie"
#                          ...
# 859                            Razi, Mr. Raihed
# 863           Sage, Miss. Dorothy Edith "Dolly"
# 868                 van Melkebeke, Mr. Philemon
# 878                          Laleff, Mr. Kristo
# 888    Johnston, Miss. Catherine Helen "Carrie"
# Name: Name, Length: 177, dtype: object

# %%
df[df['Fare']==max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258            0         1       1                    Ward, Miss. Anna
# 679            0         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737            0         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#       sudh
# 258  kumar
# 679  kumar
# 737  kumar

# %%
df[(df['SibSp']==1) & (df['Cabin']=='C85')]
# Out:
#    PassengerId  Survived  Pclass  \
# 1            0         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch    Ticket     Fare Cabin Embarked   sudh
# 1      0  PC 17599  71.2833   C85        C  kumar

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            0         0       3
# 1            0         1       1
# 2            0         1       3
# 3            0         1       1
# 4            0         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   sudh
# 0      0         A/5 21171   7.2500   NaN        S  kumar
# 1      0          PC 17599  71.2833   C85        C  kumar
# 2      0  STON/O2. 3101282   7.9250   NaN        S  kumar
# 3      0            113803  53.1000  C123        S  kumar
# ...

# %%
df['xyz']= df['Pclass'] + df['SibSp']

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            0         0       3
# 1            0         1       1
# 2            0         1       3
# 3            0         1       1
# 4            0         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   sudh  xyz
# 0      0         A/5 21171   7.2500   NaN        S  kumar    4
# 1      0          PC 17599  71.2833   C85        C  kumar    2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  kumar    3
# ...

# %%
df[df['Age']==max(df['Age'])][['Name','Age']]
# Out:
#                                      Name   Age
# 630  Barkworth, Mr. Algernon Henry Wilson  80.0

# %%
df.drop('sudh',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              0         0       3
# 1              0         1       1
# 2              0         1       3
# 3              0         1       1
# 4              0         0       3
# ..           ...       ...     ...
# 886            0         0       2
# 887            0         1       1
# 888            0         0       3
# 889            0         1       1
# 890            0         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.drop(['xyz','PassengerId'],axis=1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.drop(1,inplace=True)

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df[df['Age']> 30]
# Out:
#      Survived  Pclass                                           Name     Sex  \
# 3           1       1   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                       Allen, Mr. William Henry    male
# 6           0       1                        McCarthy, Mr. Timothy J    male
# 11          1       1                       Bonnell, Miss. Elizabeth  female
# 13          0       3                    Andersson, Mr. Anders Johan    male
# ..        ...     ...                                            ...     ...
# 873         0       3                    Vander Cruyssen, Mr. Victor    male
# 879         1       1  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 881         0       3                             Markun, Mr. Johann    male
# 885         0       3           Rice, Mrs. William (Margaret Norton)  female
# 890         0       3                            Dooley, Mr. Patrick    male
#
# ...

# %%
df.iloc[np.where(df['Age']>30)]
# Out:
#      Survived  Pclass                                           Name     Sex  \
# 3           1       1   Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                       Allen, Mr. William Henry    male
# 6           0       1                        McCarthy, Mr. Timothy J    male
# 11          1       1                       Bonnell, Miss. Elizabeth  female
# 13          0       3                    Andersson, Mr. Anders Johan    male
# ..        ...     ...                                            ...     ...
# 873         0       3                    Vander Cruyssen, Mr. Victor    male
# 879         1       1  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female
# 881         0       3                             Markun, Mr. Johann    male
# 885         0       3           Rice, Mrs. William (Margaret Norton)  female
# 890         0       3                            Dooley, Mr. Patrick    male
#
# ...

# %%
df.dropna()
# Out:
#      Survived  Pclass                                              Name  \
# 3           1       1      Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 6           0       1                           McCarthy, Mr. Timothy J
# 10          1       3                   Sandstrom, Miss. Marguerite Rut
# 11          1       1                          Bonnell, Miss. Elizabeth
# 21          1       2                             Beesley, Mr. Lawrence
# ..        ...     ...                                               ...
# 871         1       1  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 872         0       1                          Carlsson, Mr. Frans Olof
# 879         1       1     Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 887         1       1                      Graham, Miss. Margaret Edith
# 889         1       1                             Behr, Mr. Karl Howell
#
#         Sex   Age  SibSp  Parch   Ticket     Fare        Cabin Embarked
# ...

# %%
df.dropna(axis=1)
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
#      SibSp  Parch            Ticket     Fare
# ...

# %%
df1=df.tail(10)

# %%
df1.dropna(thresh=2)
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 881         0       3                        Markun, Mr. Johann    male  33.0
# 882         0       3              Dahlberg, Miss. Gerda Ulrika  female  22.0
# 883         0       2             Banfield, Mr. Frederick James    male  28.0
# 884         0       3                    Sutehall, Mr. Henry Jr    male  25.0
# 885         0       3      Rice, Mrs. William (Margaret Norton)  female  39.0
# 886         0       2                     Montvila, Rev. Juozas    male  27.0
# 887         1       1              Graham, Miss. Margaret Edith  female  19.0
# 888         0       3  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889         1       1                     Behr, Mr. Karl Howell    male  26.0
# 890         0       3                       Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df1.dropna(thresh=10)
# Out:
#      Survived  Pclass                                  Name     Sex   Age  \
# 881         0       3                    Markun, Mr. Johann    male  33.0
# 882         0       3          Dahlberg, Miss. Gerda Ulrika  female  22.0
# 883         0       2         Banfield, Mr. Frederick James    male  28.0
# 884         0       3                Sutehall, Mr. Henry Jr    male  25.0
# 885         0       3  Rice, Mrs. William (Margaret Norton)  female  39.0
# 886         0       2                 Montvila, Rev. Juozas    male  27.0
# 887         1       1          Graham, Miss. Margaret Edith  female  19.0
# 889         1       1                 Behr, Mr. Karl Howell    male  26.0
# 890         0       3                   Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# 881      0      0            349257   7.8958   NaN        S
# 882      0      0              7552  10.5167   NaN        S
# ...

# %%
df1.dropna(thresh=11)
# Out:
#      Survived  Pclass                          Name     Sex   Age  SibSp  \
# 887         1       1  Graham, Miss. Margaret Edith  female  19.0      0
# 889         1       1         Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 887      0  112053  30.0   B42        S
# 889      0  111369  30.0  C148        C

# %%
df1
# Out:
#      Survived  Pclass                                      Name     Sex   Age  \
# 881         0       3                        Markun, Mr. Johann    male  33.0
# 882         0       3              Dahlberg, Miss. Gerda Ulrika  female  22.0
# 883         0       2             Banfield, Mr. Frederick James    male  28.0
# 884         0       3                    Sutehall, Mr. Henry Jr    male  25.0
# 885         0       3      Rice, Mrs. William (Margaret Norton)  female  39.0
# 886         0       2                     Montvila, Rev. Juozas    male  27.0
# 887         1       1              Graham, Miss. Margaret Edith  female  19.0
# 888         0       3  Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889         1       1                     Behr, Mr. Karl Howell    male  26.0
# 890         0       3                       Dooley, Mr. Patrick    male  32.0
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df1.dropna(thresh=11)
# Out:
#      Survived  Pclass                          Name     Sex   Age  SibSp  \
# 887         1       1  Graham, Miss. Margaret Edith  female  19.0      0
# 889         1       1         Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 887      0  112053  30.0   B42        S
# 889      0  111369  30.0  C148        C

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df.fillna(value='sudh')
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df.fillna(value=df['Age'].mean())
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df['Age']=df['Age'].replace('NaN',df['Age'].mean())

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
df['Age']=df['Age'].replace(np.NaN,df['Age'].mean())

# %%
df
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                       Braund, Mr. Owen Harris    male
# 2           1       3                        Heikkinen, Miss. Laina  female
# 3           1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4           0       3                      Allen, Mr. William Henry    male
# 5           0       3                              Moran, Mr. James    male
# ..        ...     ...                                           ...     ...
# 886         0       2                         Montvila, Rev. Juozas    male
# 887         1       1                  Graham, Miss. Margaret Edith  female
# 888         0       3      Johnston, Miss. Catherine Helen "Carrie"  female
# 889         1       1                         Behr, Mr. Karl Howell    male
# 890         0       3                           Dooley, Mr. Patrick    male
#
# ...

# %%
#https://archive.ics.uci.edu/ml/datasets/Activity+Recognition+system+based+on+Multisensor+data+fusion+%28AReM%29
